# %%
import pandas as pd
import json
from pandas import json_normalize
#df = pd.read_json('./Data/data.json')
with open('./Data/data.json', 'r', encoding='utf-16') as file:
    data = json.load(file)

df = pd.DataFrame(data)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[106], line 3
#       1 import pandas as pd
#       2 import json
# ----> 3 from pandas import json
#       4 #df = pd.read_json('./Data/data.json')
#       5 with open('./Data/data.json', 'r', encoding='utf-16') as file:
#
# ImportError: cannot import name 'json' from 'pandas' (E:\models\Lib\site-packages\pandas\__init__.py)

# %%
aa = df.columns.tolist()
df = df.T
#list = pd.DataFrame(aa)
#res = pd.concat([df, list], axis=1)
df.items
# Out:
# <bound method DataFrame.items of              2021-01-01 00:20            2021-01-01 00:50 2021-01-01 01:20  \
# 0                           3                           2                2
# 1                          93                          93              100
# 2                           7                          11                7
# 3                        1004                        1004             1004
# 4  Light rain. Mostly cloudy.  Light rain. Mostly cloudy.   Mostly cloudy.
#
#   2021-01-01 01:50 2021-01-01 02:20 2021-01-01 02:50 2021-01-01 03:20  \
# 0                2                2                2                2
# 1              100              100               93               93
# 2                4                4                2                4
# 3             1004             1004             1004             1005
# 4   Mostly cloudy.   Mostly cloudy.   Mostly cloudy.      Low clouds.
#
# ...

# %%
df
#dt.columns = ['date&time', 'temperature (°C)', 'humidity (%)', 'wind_speed (km/h)', 'precipitation']
# Out:
#                     0    1    2     3                           4  \
# 2021-01-01 00:20    3   93    7  1004  Light rain. Mostly cloudy.
# 2021-01-01 00:50    2   93   11  1004  Light rain. Mostly cloudy.
# 2021-01-01 01:20    2  100    7  1004              Mostly cloudy.
# 2021-01-01 01:50    2  100    4  1004              Mostly cloudy.
# 2021-01-01 02:20    2  100    4  1004              Mostly cloudy.
# ...               ...  ...  ...   ...                         ...
# 16988             NaN  NaN  NaN   NaN                         NaN
# 16989             NaN  NaN  NaN   NaN                         NaN
# 16990             NaN  NaN  NaN   NaN                         NaN
# 16991             NaN  NaN  NaN   NaN                         NaN
# 16992             NaN  NaN  NaN   NaN                         NaN
#
#                                  0
# 2021-01-01 00:20               NaN
# 2021-01-01 00:50               NaN
# 2021-01-01 01:20               NaN
# ...

# %%
dt.to_csv('./Data/weather_data.csv', index=False)

# %%
# Out:
# C:\Users\bachm\AppData\Local\Temp\ipykernel_5380\3636380351.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   dt['date&time'] = pd.to_datetime(dt['date&time'])
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 dt['date&time'] = pd.to_datetime(dt['date&time'])
#       2 dt.set_index('date', inplace=True)
#
# File E:\models\Lib\site-packages\pandas\core\tools\datetimes.py:1063, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1061             result = arg.tz_localize("utc")
#    1062 elif isinstance(arg, ABCSeries):
# -> 1063     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1064     if not cache_array.empty:
# ...
